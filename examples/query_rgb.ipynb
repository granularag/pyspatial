# %%
# %load_ext autoreload

# %%
# %autoreload 2

# %%
# %matplotlib inline

# %%
from pyspatial.raster import read_raster, read_band, RasterBand
from pyspatial.vector import read_layer, read_geojson
from osgeo import gdal
import numpy as np
import matplotlib.pyplot as plt
from collections import Counter

# %%
# A polygon around carlyle lake
vl, vldf = read_geojson("../test/data/vector/carlyle_lake.geojson")

# %%
rd = read_raster("../test/data/raster/95000_45000_rgb.tif.gz")
rbs = []
for i in range(1, 4):
    rbs.append(RasterBand("../test/data/raster/95000_45000_rgb.tif.gz", band_number=i))

# %%
# Visualize the bands
plt.imshow(np.array(rbs).transpose([1,2,0]))

# %%
colors = zip(*list(rd.query(vl))[0].values)

# %%
counter = Counter(test)

# %%
csum = sum(counter.values())

# %%
# Output the fractions of each color, here water is the majority as expected.
for k, v in counter.items():
    print k , v*1./csum
# Out:
# (255, 158, 12) 0.000124106196718
# (38, 112, 0) 0.0632273339125
# (255, 211, 0) 0.0892705419622
# (155, 155, 155) 0.0625065633085
# (204, 191, 163) 0.000128879511976
# (112, 0, 73) 4.77331525838e-06
# (165, 112, 0) 0.00154178082846
# (127, 178, 178) 0.00558000553705
# (255, 165, 226) 0.0029355888839
# (112, 112, 0) 0.0374180183104
# (191, 191, 119) 2.38665762919e-05
# (232, 191, 255) 3.34132068087e-05
# (232, 255, 191) 0.0559241615672
# (76, 112, 163) 0.535799864438
# (147, 204, 147) 0.14521379679
# (165, 242, 140) 0.000267305654469

# %%
from IPython.display import HTML

HTML("""
<p>The major color</p>
<style>
.square {
  float: left;
  width: 20px;
  height: 20px;
  margin: 5px;
  border: 1px solid rgba(0, 0, 0, .2);
}

.blue {
  background: rgb(76,112,163);
}
</style>
<div class="square blue"></div>""")
# Out:
# <p>The major color</p>
# <style>
# .square {
#   float: left;
#   width: 20px;
#   height: 20px;
#   margin: 5px;
#   border: 1px solid rgba(0, 0, 0, .2);
# }
#
# .blue {
#   background: rgb(76,112,163);
# }
# </style>
# <div class="square blue"></div>
